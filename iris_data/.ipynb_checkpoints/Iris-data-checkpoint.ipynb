# %% [markdown]
# # Iris Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
files = os.listdir(os.curdir)        
print(files)                               #looking inside the current directory
# Out:
# ['.DS_Store', '.ipynb_checkpoints', 'bezdekIris.txt', 'iris-classification.ipynb', 'Iris-data.ipynb', 'iris.txt']

# %% [markdown]
# # import data

# %%
df=pd.read_csv('iris.txt',header=None)
df.columns=['sepal$len','sepal$width','petal$len','petal$wid','type'] # Renaming the heading

# %%
df.head() #view data frame
# Out:
#    sepal$len  sepal$width  petal$len  petal$wid         type
# 0        5.1          3.5        1.4        0.2  Iris-setosa
# 1        4.9          3.0        1.4        0.2  Iris-setosa
# 2        4.7          3.2        1.3        0.2  Iris-setosa
# 3        4.6          3.1        1.5        0.2  Iris-setosa
# 4        5.0          3.6        1.4        0.2  Iris-setosa

# %%
# This function gives your differnt types within an array
def types(array):   
    newarray=[]
    for a in range(len(array)):
        if array[a] not in newarray:
            newarray.append(array[a])
    return newarray

# %%
types(np.asarray(df)[:,4]) # so we see that therea are three different types
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
# this simply counts how many of each type we have
dfarray=np.asarray(df)
def count(array,word):
    i=0
    for a in range(len(array)):
        if array[a]==word:
            i=i+1
    return i

# %%
# creates a table for iris-setosa
num_setosa=count(np.asarray(df)[:,4],'Iris-setosa')
setosa_array=np.zeros((num_setosa,len(dfarray[1])-1))
for a in range(len(dfarray)):
    if dfarray[a,4]=='Iris-setosa':
        setosa_array[a,0:4]=dfarray[a,0:4]

# %%
# creates a table for iris-versicolor
num_versicolor=count(np.asarray(df)[:,4],'Iris-versicolor')
versicolor_array=np.zeros((num_versicolor,len(dfarray[1])-1))
i=0
for a in range(len(dfarray)):
    if dfarray[a,4]=='Iris-versicolor':
        versicolor_array[i,0:4]=dfarray[a,0:4]
        i=i+1

# %%
# creates a table for iris-virginica
num_virginica=count(np.asarray(df)[:,4],'Iris-virginica')
virginica_array=np.zeros((num_virginica,len(dfarray[1])-1))
i=0
for a in range(len(dfarray)):
    if dfarray[a,4]=='Iris-virginica':
        virginica_array[i,0:4]=dfarray[a,0:4]
        i=i+1

# %% [markdown]
# # Plotting the data

# %%
df.plot.scatter(x="sepal$len", y="sepal$width") #Plot the whole data set
plt.show()

# %%
plt.scatter(x=setosa_array[:,0],y=setosa_array[:,1], marker="s",color="r",label='setosa')
plt.scatter(x=versicolor_array[:,0],y=versicolor_array[:,1], marker="o",color="g",label='versicolor')
plt.scatter(x=virginica_array[:,0],y=virginica_array[:,1], marker="x",color="b",label='virginica')
plt.xlabel('sepal$len')
plt.ylabel('sepal$width')
plt.legend(loc='upper right')
plt.show()

# %%
df.plot.scatter(x="petal$len", y="petal$wid") #Plot the whole data set
plt.show()

# %%
plt.scatter(x=setosa_array[:,2],y=setosa_array[:,3], marker="s",color="r",label='setosa')
plt.scatter(x=versicolor_array[:,2],y=versicolor_array[:,3], marker="o",color="g",label='versicolor')
plt.scatter(x=virginica_array[:,2],y=virginica_array[:,3], marker="x",color="b",label='virginica')
plt.xlabel('petal$len')
plt.ylabel('petal$width')
plt.legend(loc='upper left')
plt.show()

# %%
df.plot.scatter(x="sepal$len", y="petal$len") #Plot the whole data set
plt.show()

# %%
plt.scatter(x=setosa_array[:,0],y=setosa_array[:,2], marker="s",color="r",label='setosa')
plt.scatter(x=versicolor_array[:,0],y=versicolor_array[:,2], marker="o",color="g",label='versicolor')
plt.scatter(x=virginica_array[:,0],y=virginica_array[:,2], marker="x",color="b",label='virginica')
plt.xlabel('sepal$len')
plt.ylabel('petal$len')
plt.legend(loc='upper left')
plt.show()

# %%
df.plot.scatter(x="sepal$width", y="petal$wid") #Plot the whole data set
plt.show()

# %%
plt.scatter(x=setosa_array[:,1],y=setosa_array[:,3], marker="s",color="r",label='setosa')
plt.scatter(x=versicolor_array[:,1],y=versicolor_array[:,3], marker="o",color="g",label='versicolor')
plt.scatter(x=virginica_array[:,1],y=virginica_array[:,3], marker="x",color="b",label='virginica')
plt.xlabel('sepal$width')
plt.ylabel('petal$wid')
plt.legend(loc='center right')
plt.show()

# %%
#Before performing complicated classification problem lets 
# use linear regression to perdict serosa.
#In particular, look at petal$len vs petal widthplot

# %%
df.plot.scatter(x="petal$len", y="petal$wid") #Plot the whole data set
plt.show()

# %%
plt.scatter(x=setosa_array[:,2],y=setosa_array[:,3], marker="s",color="r",label='setosa')
plt.scatter(x=versicolor_array[:,2],y=versicolor_array[:,3], marker="o",color="g",label='versicolor')
plt.scatter(x=virginica_array[:,2],y=virginica_array[:,3], marker="x",color="b",label='virginica')
from pylab import *
x=[]
for a in dfarray[:,2]:
    x.append(a)
y=[]
for a in dfarray[:,3]:
    y.append(a)
(a,b)=polyfit(x,y,1)
x=range(8)
plt.plot(x,a*x+b)
plt.plot(x,0.8-2.5*b+x*b)# this is my decision boundary line
plt.xlabel('petal$len')
plt.ylabel('petal$width')
plt.legend(loc='center right')
plt.show()

# %%
def is_setosa(sepal_len,sepal_wid,petal_len,petal_wid): #determines whether it falls under setosa class or not
    if petal_wid<0.8-2.5*b+petal_len*b:
        return True
    else:
        return False

# %%
is_setosa(dfarray[25,0],dfarray[25,1],dfarray[25,2],dfarray[25,3])
# Out:
# True

# %% [raw]
# # This is simple use of liner regression to classification problem. We can have
# # another decision boundary between the green and blue dots but the boundar is not
# # going to be very clear. So it might be better to use other methods
