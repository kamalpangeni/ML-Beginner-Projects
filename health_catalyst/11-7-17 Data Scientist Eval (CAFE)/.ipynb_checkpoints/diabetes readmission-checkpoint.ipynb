# %% [markdown]
# # Diabetes readmission problem

# %% [markdown]
# First we start by importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('training_data.csv',index_col='encounter_id')  #importing files in dataframe

# %%
df.head() # look at the head of data
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code    ...      \
# encounter_id                                                      ...
# 2278392                         1                 1          ?    ...
# 149190                          7                 3          ?    ...
# 64410                           7                 2          ?    ...
# 500364                          7                 2          ?    ...
# 16680                           7                 1          ?    ...
#
#              citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# encounter_id
# 2278392               No       No                   No                   No
# 149190                No       Up                   No                   No
# 64410                 No       No                   No                   No
# 500364                No       Up                   No                   No
# 16680                 No   Steady                   No                   No
#
#               glimepiride-pioglitazone  metformin-rosiglitazone  \
# encounter_id
# 2278392                             No                       No
# 149190                              No                       No
# 64410                               No                       No
# 500364                              No                       No
# 16680                               No                       No
#
#               metformin-pioglitazone change diabetesMed readmitted
# encounter_id
# 2278392                           No     No          No          N
# 149190                            No     Ch         Yes          N
# 64410                             No     No         Yes          N
# 500364                            No     Ch         Yes          N
# 16680                             No     Ch         Yes          N
#
# [5 rows x 49 columns]

# %%
df['weight'].value_counts()
# Out:
# ?            78844
# [75-100)      1075
# [50-75)        718
# [100-125)      509
# [125-150)      120
# [25-50)         70
# [0-25)          39
# [150-175)       29
# [175-200)        8
# >200             2
# Name: weight, dtype: int64

# %% [markdown]
# Lets see if we can guess the missing weights

# %%
df[(df['race']=='Caucasian')&(df['gender']=='Male')&(df['age']=='[40-50)')]['weight'].value_counts()
# Out:
# ?            2465
# [75-100)       30
# [100-125)      22
# [125-150)      11
# [50-75)        11
# [0-25)          3
# [175-200)       3
# [25-50)         2
# [150-175)       2
# Name: weight, dtype: int64

# %% [markdown]
# We have a lot of missing data and the age range differs a lot within given race, gender and age so I
# think it is better to not use this column in classification problem

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['readmitted'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81414 entries, 2278392 to 443867222
# Data columns (total 49 columns):
# patient_nbr                 81414 non-null int64
# race                        81414 non-null object
# gender                      81414 non-null object
# age                         81414 non-null object
# weight                      81414 non-null object
# admission_type_id           81414 non-null int64
# discharge_disposition_id    81414 non-null int64
# admission_source_id         81414 non-null int64
# time_in_hospital            81414 non-null int64
# payer_code                  81414 non-null object
# medical_specialty           81414 non-null object
# num_lab_procedures          81414 non-null int64
# num_procedures              81414 non-null int64
# num_medications             81414 non-null int64
# number_outpatient           81414 non-null int64
# number_emergency            81414 non-null int64
# number_inpatient            81414 non-null int64
# diag_1                      81414 non-null object
# diag_2                      81414 non-null object
# diag_3                      81414 non-null object
# number_diagnoses            81414 non-null int64
# max_glu_serum               81414 non-null object
# A1Cresult                   81414 non-null object
# metformin                   81414 non-null object
# repaglinide                 81414 non-null object
# nateglinide                 81414 non-null object
# chlorpropamide              81414 non-null object
# glimepiride                 81414 non-null object
# acetohexamide               81414 non-null object
# glipizide                   81414 non-null object
# glyburide                   81414 non-null object
# tolbutamide                 81414 non-null object
# pioglitazone                81414 non-null object
# rosiglitazone               81414 non-null object
# acarbose                    81414 non-null object
# miglitol                    81414 non-null object
# troglitazone                81414 non-null object
# tolazamide                  81414 non-null object
# examide                     81414 non-null object
# citoglipton                 81414 non-null object
# insulin                     81414 non-null object
# glyburide-metformin         81414 non-null object
# glipizide-metformin         81414 non-null object
# glimepiride-pioglitazone    81414 non-null object
# metformin-rosiglitazone     81414 non-null object
# metformin-pioglitazone      81414 non-null object
# change                      81414 non-null object
# diabetesMed                 81414 non-null object
# readmitted                  81414 non-null object
# dtypes: int64(12), object(37)
# memory usage: 33.6+ MB

# %%
plt.figure(figsize=(13,7))
sns.countplot(df['readmitted'],hue=df['race'])

# %%
df[df['readmitted']=='Y']['race'].value_counts()/df[df['readmitted']=='Y']['race'].value_counts().sum()
# Out:
# Caucasian          0.754347
# AfricanAmerican    0.191283
# Hispanic           0.019150
# ?                  0.017169
# Other              0.012217
# Asian              0.005833
# Name: race, dtype: float64

# %%
df[df['readmitted']=='N']['race'].value_counts()/df[df['readmitted']=='N']['race'].value_counts().sum()
# Out:
# Caucasian          0.746433
# AfricanAmerican    0.189069
# ?                  0.022910
# Hispanic           0.019951
# Other              0.015278
# Asian              0.006360
# Name: race, dtype: float64

# %% [markdown]
# So, looks like race is really not a factor in readmission

# %%
plt.figure(figsize=(13,7))
sns.countplot(x='readmitted',hue='age',data=df)

# %%
df[df['readmitted']=='Y']['age'].value_counts()/df[df['readmitted']=='Y']['age'].value_counts().sum()
# Out:
# [70-80)     0.270086
# [60-70)     0.221660
# [80-90)     0.181928
# [50-60)     0.146929
# [40-50)     0.091680
# [30-40)     0.036540
# [90-100)    0.027185
# [20-30)     0.020361
# [10-20)     0.003412
# [0-10)      0.000220
# Name: age, dtype: float64

# %%
df[df['readmitted']=='N']['age'].value_counts()/df[df['readmitted']=='N']['age'].value_counts().sum()
# Out:
# [70-80)     0.254894
# [60-70)     0.221837
# [50-60)     0.171455
# [80-90)     0.167943
# [40-50)     0.095053
# [30-40)     0.037150
# [90-100)    0.027223
# [20-30)     0.015582
# [10-20)     0.007134
# [0-10)      0.001728
# Name: age, dtype: float64

# %% [markdown]
# Among readmitted age group 50-60 makes 54 percent while among not-readmitted age group 50-60 makes 67 percent.
# so this might have some information so we will keep this column.

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['readmitted'],hue=df['gender'])

# %%
df[df['readmitted']=='Y']['gender'].value_counts()/df[df['readmitted']=='Y']['gender'].value_counts().sum()
# Out:
# Female    0.53764
# Male      0.46236
# Name: gender, dtype: float64

# %%
df[df['readmitted']=='N']['gender'].value_counts()/df[df['readmitted']=='N']['gender'].value_counts().sum()
# Out:
# Female             0.537371
# Male               0.462601
# Unknown/Invalid    0.000028
# Name: gender, dtype: float64

# %% [markdown]
# gender doesnt seem to play any role

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['readmitted'],hue=df['diabetesMed'])

# %%
df[df['readmitted']=='Y']['diabetesMed'].value_counts()/df[df['readmitted']=='Y']['diabetesMed'].value_counts().sum()
# Out:
# Yes    0.802884
# No     0.197116
# Name: diabetesMed, dtype: float64

# %%
df[df['readmitted']=='N']['diabetesMed'].value_counts()/df[df['readmitted']=='N']['diabetesMed'].value_counts().sum()
# Out:
# Yes    0.76648
# No     0.23352
# Name: diabetesMed, dtype: float64

# %% [markdown]
# don't drop diabetesMed

# %%
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code    ...      \
# encounter_id                                                      ...
# 2278392                         1                 1          ?    ...
# 149190                          7                 3          ?    ...
# 64410                           7                 2          ?    ...
# 500364                          7                 2          ?    ...
# 16680                           7                 1          ?    ...
#
#              citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# encounter_id
# 2278392               No       No                   No                   No
# 149190                No       Up                   No                   No
# 64410                 No       No                   No                   No
# 500364                No       Up                   No                   No
# 16680                 No   Steady                   No                   No
#
#               glimepiride-pioglitazone  metformin-rosiglitazone  \
# encounter_id
# 2278392                             No                       No
# 149190                              No                       No
# 64410                               No                       No
# 500364                              No                       No
# 16680                               No                       No
#
#               metformin-pioglitazone change diabetesMed readmitted
# encounter_id
# 2278392                           No     No          No          N
# 149190                            No     Ch         Yes          N
# 64410                             No     No         Yes          N
# 500364                            No     Ch         Yes          N
# 16680                             No     Ch         Yes          N
#
# [5 rows x 49 columns]

# %% [markdown]
# # cleaning up the data

# %% [markdown]
# First, I will separate object columns

# %%
df['diag_1'] = pd.to_numeric(df['diag_1'], errors='coerce')
df['diag_2'] = pd.to_numeric(df['diag_1'], errors='coerce')
df['diag_3'] = pd.to_numeric(df['diag_1'], errors='coerce')

# %%
df['diag_1'].isnull().value_counts()
# Out:
# False    80071
# True      1343
# Name: diag_1, dtype: int64

# %%
df['diag_2'].isnull().value_counts()
# Out:
# False    80071
# True      1343
# Name: diag_2, dtype: int64

# %%
# fill in the diag_1, diag_2,diag_3 columns
for age in df['age'].unique():
    for gender in df['gender'].unique():
        average1 = df[(df['gender']==gender)&(df['age']==age)]['diag_1'].mean()
        average2 = df[(df['gender']==gender)&(df['age']==age)]['diag_2'].mean()
        average3 = df[(df['gender']==gender)&(df['age']==age)]['diag_3'].mean()
        df.loc[(df['gender']==gender)&(df['age']==age),'diag_1'] = df.loc[(df['gender']==gender)&(df['age']==age),'diag_1'].fillna(average1)
        df.loc[(df['gender']==gender)&(df['age']==age),'diag_2'] = df.loc[(df['gender']==gender)&(df['age']==age),'diag_2'].fillna(average2)
        df.loc[(df['gender']==gender)&(df['age']==age),'diag_3'] = df.loc[(df['gender']==gender)&(df['age']==age),'diag_3'].fillna(average3)

# %%
df['diag_1'].isnull().value_counts()
# Out:
# False    81414
# Name: diag_1, dtype: int64

# %%
#for age in df['age'].unique():
#    df.loc[df['age']==age,'age'] = pd.to_numeric(str(age).strip('[)').split('-')).mean()
#df['age'] = df['age'].astype(float)

# %%
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code     ...      \
# encounter_id                                                       ...
# 2278392                         1                 1          ?     ...
# 149190                          7                 3          ?     ...
# 64410                           7                 2          ?     ...
# 500364                          7                 2          ?     ...
# 16680                           7                 1          ?     ...
#
#              citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# encounter_id
# 2278392               No       No                   No                   No
# 149190                No       Up                   No                   No
# 64410                 No       No                   No                   No
# 500364                No       Up                   No                   No
# 16680                 No   Steady                   No                   No
#
#               glimepiride-pioglitazone  metformin-rosiglitazone  \
# encounter_id
# 2278392                             No                       No
# 149190                              No                       No
# 64410                               No                       No
# 500364                              No                       No
# 16680                               No                       No
#
#               metformin-pioglitazone  change  diabetesMed  readmitted
# encounter_id
# 2278392                           No      No           No           N
# 149190                            No      Ch          Yes           N
# 64410                             No      No          Yes           N
# 500364                            No      Ch          Yes           N
# 16680                             No      Ch          Yes           N
#
# [5 rows x 49 columns]

# %% [markdown]
# So diag columns has been filled

# %%
droplist_1=['weight','patient_nbr','admission_type_id','discharge_disposition_id',
           'admission_source_id','payer_code','medical_specialty','change']

# %%
df_obj = df.select_dtypes(include=['object'])

# %%
df_obj['miglitol'].value_counts()
# Out:
# No        81382
# Steady       27
# Down          4
# Up            1
# Name: miglitol, dtype: int64

# %% [markdown]
# From, above value count we see that most patients were not given 'miglitol'. The number of patients that were given
# are statistically insignificant

# %%
# list of columns that can be dropped because this particular medication is not
# given to enough patient to make any difference in this analysis
drop_list=[]
for col in df_obj.columns:
    if df_obj[str(col)].value_counts()[0]>(len(df_obj.index)-1000):
        drop_list.append(str(col))
print(drop_list)
# Out:
# ['nateglinide', 'chlorpropamide', 'acetohexamide', 'tolbutamide', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone']

# %%
for j in droplist_1:
    drop_list.append(j)

# %%
drop_list
# Out:
# ['nateglinide',
#  'chlorpropamide',
#  'acetohexamide',
#  'tolbutamide',
#  'acarbose',
#  'miglitol',
#  'troglitazone',
#  'tolazamide',
#  'examide',
#  'citoglipton',
#  'glyburide-metformin',
#  'glipizide-metformin',
#  'glimepiride-pioglitazone',
#  'metformin-rosiglitazone',
#  'metformin-pioglitazone',
#  'weight',
#  'patient_nbr',
#  'admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id',
#  'payer_code',
#  'medical_specialty',
#  'change']

# %% [markdown]
# Drop columns with too much missing data and that are not relevant

# %%
df1 = df.drop(drop_list,axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81414 entries, 2278392 to 443867222
# Data columns (total 26 columns):
# race                  81414 non-null object
# gender                81414 non-null object
# age                   81414 non-null object
# time_in_hospital      81414 non-null int64
# num_lab_procedures    81414 non-null int64
# num_procedures        81414 non-null int64
# num_medications       81414 non-null int64
# number_outpatient     81414 non-null int64
# number_emergency      81414 non-null int64
# number_inpatient      81414 non-null int64
# diag_1                81414 non-null float64
# diag_2                81414 non-null float64
# diag_3                81414 non-null float64
# number_diagnoses      81414 non-null int64
# max_glu_serum         81414 non-null object
# A1Cresult             81414 non-null object
# metformin             81414 non-null object
# repaglinide           81414 non-null object
# glimepiride           81414 non-null object
# glipizide             81414 non-null object
# glyburide             81414 non-null object
# pioglitazone          81414 non-null object
# rosiglitazone         81414 non-null object
# insulin               81414 non-null object
# diabetesMed           81414 non-null object
# readmitted            81414 non-null object
# dtypes: float64(3), int64(8), object(15)
# memory usage: 19.3+ MB

# %%
df1_num = df1.select_dtypes(include=['int64','float64'])

# %%
df1_num.columns
# Out:
# Index(['time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses'],
#       dtype='object')

# %%
for j in df1_num.columns:
    print(df[str(j)].value_counts())
    print('\n')
# Out:
# 3     14225
# 2     13810
# 1     11297
# 4     11158
# 5      7987
# 6      6018
# 7      4654
# 8      3523
# 9      2428
# 10     1877
# 11     1459
# 12     1166
# 13      974
# 14      838
# Name: time_in_hospital, dtype: int64
#
#
# 1      2560
# 43     2212
# 44     1968
# 45     1904
# 40     1770
# 38     1760
# 46     1742
# 41     1712
# 47     1697
# 39     1693
# 42     1656
# 48     1646
# 37     1643
# 49     1635
# 36     1557
# 50     1547
# 54     1523
# 51     1512
# 35     1507
# 52     1503
# 56     1482
# 55     1461
# 53     1459
# 57     1387
# 58     1377
# 34     1336
# 59     1325
# 61     1310
# 60     1298
# 62     1182
#        ...
# 86      101
# 87       77
# 88       73
# 89       62
# 90       52
# 91       45
# 93       45
# 92       39
# 95       39
# 94       36
# 98       25
# 97       25
# 96       21
# 101      12
# 100      12
# 99        7
# 102       7
# 108       4
# 103       4
# 105       4
# 111       3
# 106       3
# 113       2
# 114       2
# 121       1
# 129       1
# 118       1
# 109       1
# 120       1
# 132       1
# Name: num_lab_procedures, Length: 115, dtype: int64
#
#
# 0    37368
# 1    16582
# 2    10138
# 3     7544
# 6     3951
# 4     3362
# 5     2469
# Name: num_procedures, dtype: int64
#
#
# 13    4851
# 12    4769
# 11    4612
# 15    4606
# 14    4600
# 16    4361
# 10    4314
# 9     3943
# 17    3919
# 18    3619
# 8     3497
# 19    3233
# 20    2974
# 7     2789
# 21    2594
# 22    2279
# 6     2157
# 23    1944
# 24    1707
# 5     1594
# 25    1493
# 26    1271
# 27    1148
# 4     1128
# 28    1025
# 29     788
# 3      720
# 30     682
# 31     579
# 32     511
#       ...
# 45      70
# 47      60
# 48      51
# 49      46
# 52      43
# 50      42
# 56      34
# 51      31
# 53      28
# 55      26
# 54      25
# 60      20
# 57      18
# 58      17
# 59      16
# 62      13
# 61      11
# 65       9
# 63       8
# 68       7
# 64       6
# 67       5
# 66       4
# 69       3
# 72       3
# 70       1
# 74       1
# 75       1
# 79       1
# 81       1
# Name: num_medications, Length: 75, dtype: int64
#
#
# 0     68059
# 1      6841
# 2      2855
# 3      1617
# 4       875
# 5       446
# 6       232
# 7       127
# 8        79
# 9        67
# 10       44
# 11       31
# 13       26
# 12       22
# 14       21
# 15       20
# 16       13
# 17        6
# 20        4
# 21        4
# 19        3
# 18        3
# 22        2
# 23        2
# 24        2
# 36        2
# 29        2
# 40        1
# 34        1
# 37        1
# 35        1
# 26        1
# 28        1
# 27        1
# 25        1
# 42        1
# Name: number_outpatient, dtype: int64
#
#
# 0     72319
# 1      6116
# 2      1644
# 3       568
# 4       309
# 5       155
# 6        76
# 7        59
# 8        42
# 10       26
# 9        22
# 11       19
# 13       11
# 12        9
# 16        5
# 22        5
# 18        4
# 19        4
# 14        3
# 15        3
# 20        2
# 21        2
# 76        1
# 54        1
# 24        1
# 25        1
# 28        1
# 29        1
# 37        1
# 42        1
# 46        1
# 64        1
# 63        1
# Name: number_emergency, dtype: int64
#
#
# 0     54009
# 1     15745
# 2      6067
# 3      2687
# 4      1302
# 5       641
# 6       387
# 7       210
# 8       123
# 9        84
# 10       48
# 11       39
# 12       32
# 13       15
# 15        8
# 14        7
# 16        6
# 19        2
# 17        1
# 21        1
# Name: number_inpatient, dtype: int64
#
#
# 428.00    5423
# 414.00    5209
# 786.00    3225
# 410.00    2892
# 486.00    2834
# 427.00    2214
# 491.00    1798
# 715.00    1722
# 682.00    1640
# 780.00    1634
# 434.00    1614
# 996.00    1565
# 276.00    1521
# 38.00     1345
# 250.80    1338
# 599.00    1271
# 584.00    1231
# 250.60     933
# 518.00     915
# 493.00     863
# 820.00     862
# 435.00     824
# 577.00     814
# 562.00     793
# 574.00     771
# 250.70     717
# 560.00     717
# 296.00     715
# 250.13     683
# 440.00     655
#           ...
# 637.00       1
# 634.00       1
# 7.00         1
# 97.00        1
# 145.00       1
# 363.00       1
# 911.00       1
# 219.00       1
# 325.00       1
# 314.00       1
# 381.00       1
# 477.00       1
# 833.00       1
# 982.00       1
# 375.00       1
# 941.00       1
# 523.00       1
# 143.00       1
# 827.00       1
# 994.00       1
# 448.00       1
# 795.00       1
# 48.00        1
# 405.00       1
# 817.00       1
# 412.00       1
# 838.00       1
# 250.51       1
# 133.00       1
# 700.00       1
# Name: diag_1, Length: 695, dtype: int64
#
#
# 428.00    5423
# 414.00    5209
# 786.00    3225
# 410.00    2892
# 486.00    2834
# 427.00    2214
# 491.00    1798
# 715.00    1722
# 682.00    1640
# 780.00    1634
# 434.00    1614
# 996.00    1565
# 276.00    1521
# 38.00     1345
# 250.80    1338
# 599.00    1271
# 584.00    1231
# 250.60     933
# 518.00     915
# 493.00     863
# 820.00     862
# 435.00     824
# 577.00     814
# 562.00     793
# 574.00     771
# 250.70     717
# 560.00     717
# 296.00     715
# 250.13     683
# 440.00     655
#           ...
# 637.00       1
# 634.00       1
# 7.00         1
# 97.00        1
# 145.00       1
# 363.00       1
# 911.00       1
# 219.00       1
# 325.00       1
# 314.00       1
# 381.00       1
# 477.00       1
# 833.00       1
# 982.00       1
# 375.00       1
# 941.00       1
# 523.00       1
# 143.00       1
# 827.00       1
# 994.00       1
# 448.00       1
# 795.00       1
# 48.00        1
# 405.00       1
# 817.00       1
# 412.00       1
# 838.00       1
# 250.51       1
# 133.00       1
# 700.00       1
# Name: diag_2, Length: 695, dtype: int64
#
#
# 428.00    5423
# 414.00    5209
# 786.00    3225
# 410.00    2892
# 486.00    2834
# 427.00    2214
# 491.00    1798
# 715.00    1722
# 682.00    1640
# 780.00    1634
# 434.00    1614
# 996.00    1565
# 276.00    1521
# 38.00     1345
# 250.80    1338
# 599.00    1271
# 584.00    1231
# 250.60     933
# 518.00     915
# 493.00     863
# 820.00     862
# 435.00     824
# 577.00     814
# 562.00     793
# 574.00     771
# 250.70     717
# 560.00     717
# 296.00     715
# 250.13     683
# 440.00     655
#           ...
# 637.00       1
# 634.00       1
# 7.00         1
# 97.00        1
# 145.00       1
# 363.00       1
# 911.00       1
# 219.00       1
# 325.00       1
# 314.00       1
# 381.00       1
# 477.00       1
# 833.00       1
# 982.00       1
# 375.00       1
# 941.00       1
# 523.00       1
# 143.00       1
# 827.00       1
# 994.00       1
# 448.00       1
# 795.00       1
# 48.00        1
# 405.00       1
# 817.00       1
# 412.00       1
# 838.00       1
# 250.51       1
# 133.00       1
# 700.00       1
# Name: diag_3, Length: 695, dtype: int64
#
#
# 9     39601
# 5      9131
# 8      8482
# 7      8284
# 6      8105
# 4      4477
# 3      2264
# 2       802
# 1       178
# 16       32
# 10       14
# 13       12
# 11       10
# 15        9
# 12        8
# 14        5
# Name: number_diagnoses, dtype: int64

# %%
df1_num.head()
# Out:
#               time_in_hospital  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392                      1                  41               0
# 149190                       3                  59               0
# 64410                        2                  11               5
# 500364                       2                  44               1
# 16680                        1                  51               0
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
#
#               number_inpatient  diag_1  diag_2  diag_3  number_diagnoses
# encounter_id
# 2278392                      0  250.83  250.83  250.83                 1
# 149190                       0  276.00  276.00  276.00                 9
# 64410                        1  648.00  648.00  648.00                 6
# 500364                       0    8.00    8.00    8.00                 7
# 16680                        0  197.00  197.00  197.00                 5

# %%
df1_num_norm = (df1_num - df1_num.mean()) / (df1_num.max() - df1_num.min()) #Normalization

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df1_num.isnull(),yticklabels=False,xticklabels=False)  #checking for null values

# %%
df1_num_norm.head()
# Out:
#               time_in_hospital  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392              -0.261410           -0.016477       -0.223117
# 149190               -0.107564            0.120927       -0.223117
# 64410                -0.184487           -0.245485        0.610217
# 500364               -0.184487            0.006423       -0.056450
# 16680                -0.261410            0.059859       -0.223117
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392             -0.187864          -0.008707         -0.002624
# 149190               0.024636          -0.008707         -0.002624
# 64410               -0.037864           0.038912         -0.002624
# 500364              -0.000364          -0.008707         -0.002624
# 16680               -0.100364          -0.008707         -0.002624
#
#               number_inpatient    diag_1    diag_2    diag_3  number_diagnoses
# encounter_id
# 2278392              -0.030276 -0.243822 -0.243822 -0.243822         -0.428120
# 149190               -0.030276 -0.218551 -0.218551 -0.218551          0.105213
# 64410                 0.017343  0.154943  0.154943  0.154943         -0.094787
# 500364               -0.030276 -0.487628 -0.487628 -0.487628         -0.028120
# 16680                -0.030276 -0.297869 -0.297869 -0.297869         -0.161454

# %%
df1_obj = df1.select_dtypes(include=['object'])

# %%
df1_obj.head()
# Out:
#                          race  gender      age max_glu_serum A1Cresult  \
# encounter_id
# 2278392             Caucasian  Female   [0-10)          None      None
# 149190              Caucasian  Female  [10-20)          None      None
# 64410         AfricanAmerican  Female  [20-30)          None      None
# 500364              Caucasian    Male  [30-40)          None      None
# 16680               Caucasian    Male  [40-50)          None      None
#
#              metformin repaglinide glimepiride glipizide glyburide  \
# encounter_id
# 2278392             No          No          No        No        No
# 149190              No          No          No        No        No
# 64410               No          No          No    Steady        No
# 500364              No          No          No        No        No
# 16680               No          No          No    Steady        No
#
#              pioglitazone rosiglitazone insulin diabetesMed readmitted
# encounter_id
# 2278392                No            No      No          No          N
# 149190                 No            No      Up         Yes          N
# 64410                  No            No      No         Yes          N
# 500364                 No            No      Up         Yes          N
# 16680                  No            No  Steady         Yes          N

# %%
for j in df1_obj.columns:
    print(df[str(j)].value_counts())
    print('\n')
# Out:
# Caucasian          60842
# AfricanAmerican    15413
# ?                   1813
# Hispanic            1617
# Other               1216
# Asian                513
# Name: race, dtype: int64
#
#
# Female             43752
# Male               37660
# Unknown/Invalid        2
# Name: gender, dtype: int64
#
#
# [70-80)     20890
# [60-70)     18059
# [80-90)     13800
# [50-60)     13736
# [40-50)      7708
# [30-40)      3019
# [90-100)     2216
# [20-30)      1312
# [10-20)       547
# [0-10)        127
# Name: age, dtype: int64
#
#
# None    77166
# Norm     2041
# >200     1196
# >300     1011
# Name: max_glu_serum, dtype: int64
#
#
# None    67762
# >8       6594
# Norm     4011
# >7       3047
# Name: A1Cresult, dtype: int64
#
#
# No        65501
# Steady    14615
# Up          841
# Down        457
# Name: metformin, dtype: int64
#
#
# No        80187
# Steady     1096
# Up           96
# Down         35
# Name: repaglinide, dtype: int64
#
#
# No        77279
# Steady     3700
# Up          275
# Down        160
# Name: glimepiride, dtype: int64
#
#
# No        71156
# Steady     9211
# Up          608
# Down        439
# Name: glipizide, dtype: int64
#
#
# No        72929
# Steady     7378
# Up          657
# Down        450
# Name: glyburide, dtype: int64
#
#
# No        75508
# Steady     5616
# Up          191
# Down         99
# Name: pioglitazone, dtype: int64
#
#
# No        76314
# Steady     4891
# Up          147
# Down         62
# Name: rosiglitazone, dtype: int64
#
#
# No        37803
# Steady    24682
# Down       9841
# Up         9088
# Name: insulin, dtype: int64
#
#
# Yes    62733
# No     18681
# Name: diabetesMed, dtype: int64
#
#
# N    72328
# Y     9086
# Name: readmitted, dtype: int64

# %%
df1_obj_dummies=pd.get_dummies(df1_obj,drop_first=True)

# %%
df1_obj_dummies.head()
# Out:
#               race_AfricanAmerican  race_Asian  race_Caucasian  race_Hispanic  \
# encounter_id
# 2278392                          0           0               1              0
# 149190                           0           0               1              0
# 64410                            1           0               0              0
# 500364                           0           0               1              0
# 16680                            0           0               1              0
#
#               race_Other  gender_Male  gender_Unknown/Invalid  age_[10-20)  \
# encounter_id
# 2278392                0            0                       0            0
# 149190                 0            0                       0            1
# 64410                  0            0                       0            0
# 500364                 0            1                       0            0
# 16680                  0            1                       0            0
#
#               age_[20-30)  age_[30-40)      ...       pioglitazone_Steady  \
# encounter_id                                ...
# 2278392                 0            0      ...                         0
# 149190                  0            0      ...                         0
# 64410                   1            0      ...                         0
# 500364                  0            1      ...                         0
# 16680                   0            0      ...                         0
#
#               pioglitazone_Up  rosiglitazone_No  rosiglitazone_Steady  \
# encounter_id
# 2278392                     0                 1                     0
# 149190                      0                 1                     0
# 64410                       0                 1                     0
# 500364                      0                 1                     0
# 16680                       0                 1                     0
#
#               rosiglitazone_Up  insulin_No  insulin_Steady  insulin_Up  \
# encounter_id
# 2278392                      0           1               0           0
# 149190                       0           0               0           1
# 64410                        0           1               0           0
# 500364                       0           0               0           1
# 16680                        0           0               1           0
#
#               diabetesMed_Yes  readmitted_Y
# encounter_id
# 2278392                     0             0
# 149190                      1             0
# 64410                       1             0
# 500364                      1             0
# 16680                       1             0
#
# [5 rows x 48 columns]

# %% [markdown]
# I already imported the numerical columns. Next, I am gonna concat the new colums

# %%
#new_df1=pd.concat([df1_num_norm,df1_obj_dummies],axis=1)
new_df1=df1_obj_dummies

# %%
new_df1.head()
# Out:
#               race_AfricanAmerican  race_Asian  race_Caucasian  race_Hispanic  \
# encounter_id
# 2278392                          0           0               1              0
# 149190                           0           0               1              0
# 64410                            1           0               0              0
# 500364                           0           0               1              0
# 16680                            0           0               1              0
#
#               race_Other  gender_Male  gender_Unknown/Invalid  age_[10-20)  \
# encounter_id
# 2278392                0            0                       0            0
# 149190                 0            0                       0            1
# 64410                  0            0                       0            0
# 500364                 0            1                       0            0
# 16680                  0            1                       0            0
#
#               age_[20-30)  age_[30-40)      ...       pioglitazone_Steady  \
# encounter_id                                ...
# 2278392                 0            0      ...                         0
# 149190                  0            0      ...                         0
# 64410                   1            0      ...                         0
# 500364                  0            1      ...                         0
# 16680                   0            0      ...                         0
#
#               pioglitazone_Up  rosiglitazone_No  rosiglitazone_Steady  \
# encounter_id
# 2278392                     0                 1                     0
# 149190                      0                 1                     0
# 64410                       0                 1                     0
# 500364                      0                 1                     0
# 16680                       0                 1                     0
#
#               rosiglitazone_Up  insulin_No  insulin_Steady  insulin_Up  \
# encounter_id
# 2278392                      0           1               0           0
# 149190                       0           0               0           1
# 64410                        0           1               0           0
# 500364                       0           0               0           1
# 16680                        0           0               1           0
#
#               diabetesMed_Yes  readmitted_Y
# encounter_id
# 2278392                     0             0
# 149190                      1             0
# 64410                       1             0
# 500364                      1             0
# 16680                       1             0
#
# [5 rows x 48 columns]

# %%
len(new_df1.index)
# Out:
# 81414

# %% [markdown]
# # Classification with logistic regression (since this is binary classficiation problem)

# %%
X=new_df1.drop('readmitted_Y', axis=1) #because this is our target class
y=new_df1['readmitted_Y']

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression(C=0.1)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[7213    0]
#  [ 929    0]]
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94      7213
#           1       0.00      0.00      0.00       929
#
# avg / total       0.78      0.89      0.83      8142
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Next use kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=12)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#            weights='uniform')

# %%
pred_knn = knn.predict(X_test)

# %%
print(confusion_matrix(y_test,pred_knn))
print(classification_report(y_test,pred_knn))
# Out:
# [[21722     9]
#  [ 2687     7]]
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94     21731
#           1       0.44      0.00      0.01      2694
#
# avg / total       0.84      0.89      0.84     24425

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[21664    29]
#  [ 2723     9]]

# %% [markdown]
# # test set

# %%
test = pd.read_csv('test_data.csv')

# %%
test.head()
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0         15738     63555939        Caucasian  Female  [90-100)      ?
# 1         62256     49726791  AfricanAmerican  Female   [60-70)      ?
# 2        150006     22864131                ?  Female   [50-60)      ?
# 3        183930    107400762        Caucasian  Female   [80-90)      ?
# 4        248916    115196778        Caucasian  Female   [50-60)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  3                         3                    4
# 1                  3                         1                    2
# 2                  2                         1                    4
# 3                  2                         6                    1
# 4                  1                         1                    1
#
#    time_in_hospital     ...     examide citoglipton  insulin  \
# 0                12     ...          No          No   Steady
# 1                 1     ...          No          No   Steady
# 2                 2     ...          No          No     Down
# 3                11     ...          No          No       No
# 4                 2     ...          No          No   Steady
#
#    glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 0                   No                   No                        No
# 1                   No                   No                        No
# 2                   No                   No                        No
# 3                   No                   No                        No
# 4                   No                   No                        No
#
#    metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
# 0                       No                      No     Ch         Yes
# 1                       No                      No     No         Yes
# 2                       No                      No     Ch         Yes
# 3                       No                      No     No          No
# 4                       No                      No     No         Yes
#
# [5 rows x 49 columns]
